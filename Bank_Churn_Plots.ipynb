# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
data = pd.read_csv("")

# %%
zones_share = [4320, 63]
zones = ["non-churners", "churners"]
zones_colors = ['olive','cornsilk']

#plt.title("PAS Share by Regions")
plt.pie(zones_share, labels=zones, shadow=True, colors=zones_colors)
plt.legend(title='Regions', loc='lower right', bbox_to_anchor=(1.3, 0.1, 0, 0))
plt.show()

# %%
print((431/438) + (6/438))
# Out:
# 0.9977168949771689

# %%
print(4320/4383)
# Out:
# 0.9856262833675564

# %%
not_churned = {
    "silent_generation": 23,
    "boomer_generation": 388,
    "generation_x": 1278,
    "millenials": 5523,
    "genz": 751
}

churned = {
    "silent_generation": 1,
    "boomer_generation": 176,
    "generation_x": 1028,
    "millenials": 772,
    "genz": 60
}

colors = ["red", "yellow", "blue", "green", "orange"]

# %%
not_churned_values = [i for i in not_churned.values()]

# %%
not_churned_values
# Out:
# [23, 388, 1278, 5523, 751]

# %%
print(range(0, not_churned["genz"], math.ceil(round(not_churned["genz"]/5))))
# Out:
# range(0, 751, 150)

# %%
print(150*5)
# Out:
# 750

# %%
plt.stackplot([20, 400, 1500, 4000, 6000],
              range(0, not_churned["millenials"], round(not_churned["millenials"]/5)),
              range(0, not_churned["generation_x"], round(not_churned["generation_x"]/5)),
              range(0, 750, math.floor(round(not_churned["genz"]/5))),
              range(0, not_churned["boomer_generation"], round(not_churned["boomer_generation"]/5)),
              range(0, not_churned["silent_generation"], 5),
              baseline="zero",
              zorder=2,
              colors=["#AE5151", "#CF8484", "#E2B2B2", "#EFDBDB", "#F3EEEE"])
plt.grid(color="lightgray", alpha=0.5, zorder=1)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.show()

# %%
plt.stackplot([20, 400, 1500, 4000, 6000],
              range(0, not_churned["millenials"], round(not_churned["millenials"]/5)),
              range(0, not_churned["generation_x"], round(not_churned["generation_x"]/5)),
              range(0, 750, math.floor(round(not_churned["genz"]/5))),
              range(0, not_churned["boomer_generation"], round(not_churned["boomer_generation"]/5)),
              range(0, not_churned["silent_generation"], 5),
              baseline="zero",
              zorder=2,
              colors=["#AE5151", "#CF8484", "#E2B2B2", "#EFDBDB", "#F3EEEE"])
plt.grid(color="lightgray", alpha=0.5, zorder=1)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['left'].set_visible(False)
plt.gca().spines['bottom'].set_visible(False)
plt.show()
